# %%
from machine129 import meals
db = meals.meals()

# %%
# 어떤 테이블이 있지
df = db.select_query('SHOW TABLES;')
df
# Out:
#   Tables_in_mydb129
# 0              Food
# 1       dis_results
# 2           disease
# 3             meals
# 4           pred_in
# 5          pred_out

# %%
table = 'Food' # 테이블 명

df = db.select_query(f'SELECT * FROM {table};')
df
# Out:
#     class_num food_name  serving_size_g  calorie_kJ  calorie_kcal  \
# 0           0       잡곡밥          200.00     1424.00        340.00
# 1           1      배추김치           38.00       35.00          8.00
# 2           2      된장찌개          200.00      717.00        171.00
# 3           3      김치찌개          200.00      505.00        121.00
# 4           4      멸치볶음           40.00      289.00         69.00
# 5           5     시금치나물          100.00      286.00         68.00
# 6           6      가지나물          165.00      297.00         71.00
# 7           7     고사리나물           80.00      214.00         51.00
# 8           8       미역국          230.00      346.00         83.00
# 9           9        김밥          125.00      611.00        148.00
# 10         10       불고기          300.00     2034.00        486.00
# 11         11      호박볶음           75.00      375.00         90.00
# 12         12       무생채          200.00      333.00         80.00
# ...
